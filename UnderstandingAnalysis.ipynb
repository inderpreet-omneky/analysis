# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df=pd.read_csv("AdsCalculation.csv")

# %%
df2=pd.read_csv("FBdata.csv")

# %%
df.head(1)
# Out:
#                                                title  \
# 0  Help get your employees cash without selling t...
#
#                                       title_entities  account_id  creative_id  \
# 0  {"shares": 0.29116723, "employees cash": 0.708...   508650889    156138876
#
#                                                 body  \
# 0  Your employees need safe options for their equ...
#
#                                               source ad_type         cta  \
# 0  https://omneky.s3.us-east-2.amazonaws.com/link...   VIDEO  LEARN_MORE
#
#                                     landing_page_url  \
# 0  https://www.getquid.com/?utm_medium=cpc&utm_so...
#
#                                        body_entities      spend  \
# 0  {"cash": 0.013456234, "fees": 0.012353965, "fu...  18.723877
#
#                                        text_entities  \
# 0  {"cash": 0.013456234, "fees": 0.012353965, "fu...
#
#                                       video_entities  clicks  impressions  \
# ...

# %%
df2
# Out:
#                                           adset_name  \
# 0       FB_IOS_CPI_ZZ_FABULOUS_AAA_VideoOnly_ID_0132
# 1    FB_ANDROID_CPA_ZZ_FABULOUS_Tier1_AAA_PS_ID_0112
# 2            FB_IOS_CPA_US_FABULOUS_AAA_HpSS_ID_0088
# 3           FB_IOS_CPI_US_FABULOUS_VideoOnly_ID_0081
# 4  FB_ANDROID_CPA_ZZ_FABULOUS_Asia_AAA_Sub1h_ID_0114
# 5          FB_ANDROID_CPA_US_FABULOUS_AAA_PS_ID_0111
# 6  FB_ANDROID_CPA_ZZ_FABULOUS_MENA_AAA_Sub1h_ID_0115
# 7              FB_IOS_CPA_US_FABULOUS_AAA_PS_ID_0133
# 8              FB_IOS_CPA_US_FABULOUS_AAA_PS_ID_0133
#
#                                        campaign_name   type  \
# 0  FB_IOS_CPI_ZZ_FABULOUS_Tier1_AAA_VideoOnly_ID_...  VIDEO
# 1    FB_ANDROID_CPA_ZZ_FABULOUS_Tier1_AAA_PS_ID_0112  SHARE
# 2            FB_IOS_CPA_US_FABULOUS_AAA_HpSS_ID_0088  VIDEO
# 3           FB_IOS_CPI_US_FABULOUS_VideoOnly_ID_0081  VIDEO
# 4  FB_ANDROID_CPA_ZZ_FABULOUS_Asia_AAA_Sub1h_ID_0114  VIDEO
# 5          FB_ANDROID_CPA_US_FABULOUS_AAA_PS_ID_0111  SHARE
# ...

# %%
# Check if every entry in each column is {}
is_all_empty = df2.apply(lambda x: all(x == '{}'))

# Get column names where all entries are {}
columns_to_drop = is_all_empty[is_all_empty].index.tolist()

# Drop the columns
df2.drop(columns=columns_to_drop, inplace=True)

# %%
df2
# Out:
#                                           adset_name  \
# 0       FB_IOS_CPI_ZZ_FABULOUS_AAA_VideoOnly_ID_0132
# 1    FB_ANDROID_CPA_ZZ_FABULOUS_Tier1_AAA_PS_ID_0112
# 2            FB_IOS_CPA_US_FABULOUS_AAA_HpSS_ID_0088
# 3           FB_IOS_CPI_US_FABULOUS_VideoOnly_ID_0081
# 4  FB_ANDROID_CPA_ZZ_FABULOUS_Asia_AAA_Sub1h_ID_0114
# 5          FB_ANDROID_CPA_US_FABULOUS_AAA_PS_ID_0111
# 6  FB_ANDROID_CPA_ZZ_FABULOUS_MENA_AAA_Sub1h_ID_0115
# 7              FB_IOS_CPA_US_FABULOUS_AAA_PS_ID_0133
# 8              FB_IOS_CPA_US_FABULOUS_AAA_PS_ID_0133
#
#                                        campaign_name   type  \
# 0  FB_IOS_CPI_ZZ_FABULOUS_Tier1_AAA_VideoOnly_ID_...  VIDEO
# 1    FB_ANDROID_CPA_ZZ_FABULOUS_Tier1_AAA_PS_ID_0112  SHARE
# 2            FB_IOS_CPA_US_FABULOUS_AAA_HpSS_ID_0088  VIDEO
# 3           FB_IOS_CPI_US_FABULOUS_VideoOnly_ID_0081  VIDEO
# 4  FB_ANDROID_CPA_ZZ_FABULOUS_Asia_AAA_Sub1h_ID_0114  VIDEO
# 5          FB_ANDROID_CPA_US_FABULOUS_AAA_PS_ID_0111  SHARE
# ...

# %%
df=pd.read_csv("Trydata.csv")

# %%
df
# Out:
#                   id                                    adset_name  \
# 0  23853845984630413  FB_IOS_CPI_ZZ_FABULOUS_AAA_VideoOnly_ID_0132
#
#                                        campaign_name   type  \
# 0  FB_IOS_CPI_ZZ_FABULOUS_Tier1_AAA_VideoOnly_ID_...  VIDEO
#
#                   cta  status                          landing_page_url   cpp  \
# 0  INSTALL_MOBILE_APP     NaN  http://itunes.apple.com/app/id1203637303  2.76
#
#    link_clicks   reach   ctr   cpm   cpc  roas  cpl   cpi  cpreg  cpatc  \
# 0          946  215533  0.59  2.59  0.62   0.0    0  1.31      0   26.5
#
#    clicks  impressions   spend  \
# 0    1325       225082  583.05
#
#                                       video_entities  \
# 0  {'song': 0.4340702295303345, 'thigh': 0.314954...
#
#                                  video_text_entities
# 0  {'reedom': 0.9948490262031555, '*****': 0.8607...

# %%
df.columns.tolist()
# Out:
# ['id',
#  'adset_name',
#  'campaign_name',
#  'type',
#  'cta',
#  'status',
#  'landing_page_url',
#  'cpp',
#  'link_clicks',
#  'reach',
#  'ctr',
#  'cpm',
#  'cpc',
#  'roas',
#  'cpl',
#  'cpi',
#  'cpreg',
#  'cpatc',
#  'clicks',
#  'impressions',
#  'spend',
#  'video_entities',
#  'video_text_entities']

# %%
a=['id', 'adset_name', 'campaign_name', 'type', 'cta', 'status', 'landing_page_url', 'cpp', 'link_clicks', 'reach', 'ctr', 'cpm', 'cpc', 'roas', 'cpl', 'cpi', 'cpreg', 'cpatc', 'clicks', 'impressions', 'spend', 'video_entities', 'video_text_entities', 'title_entities', 'body_entities', 'account_id', 'video_entities_physical exercise', 'video_entities_concrete', 'video_entities_telephone', 'video_entities_shorts', 'video_entities_wrist', 'video_entities_container', 'video_entities_leg', 'video_entities_tap', 'video_entities_room', 'video_entities_knee', 'video_entities_fashion', 'video_entities_mobile phone', 'video_entities_chemistry', 'video_entities_science', 'video_entities_gym', 'video_entities_hat', 'video_entities_material', 'video_entities_finger', 'video_entities_clock', 'video_entities_picture frame', 'video_entities_arm', 'video_entities_display device', 'video_entities_shoe', 'video_entities_exercise machine', 'video_entities_computer', 'video_entities_person', 'video_entities_physical fitness', 'video_entities_packaged goods', 'video_entities_treadmill', 'video_entities_glass', 'video_entities_pants', 'video_entities_luggage & bags', 'video_entities_bed', 'video_entities_thigh', 'video_entities_calf', 'video_entities_furniture', 'video_entities_water', 'video_entities_hip', 'video_entities_mobile device', 'video_entities_hand', 'video_entities_houseplant', 'video_entities_liquid', 'video_entities_human leg', 'video_entities_ankle', 'video_entities_smartphone', 'video_entities_music', 'video_entities_food', 'video_entities_footwear', 'video_entities_foot', 'video_entities_drink', 'video_entities_sole', 'video_entities_watch', 'video_entities_skirt', 'video_entities_sports', 'video_entities_exercise equipment', 'video_entities_text', 'video_entities_thumb', 'video_entities_song', 'video_entities_car', 'video_entities_joint', 'video_entities_pillow', 'video_entities_human body', 'video_entities_trunk', 'video_entities_lemon', 'video_entities_tableware', 'video_entities_top', 'video_entities_beaker', 'video_entities_plant', 'video_entities_signage', 'video_entities_trousers', 'video_entities_tire', 'video_entities_bag', 'video_entities_road', 'video_entities_ring', 'video_entities_lid', 'video_entities_team sport', 'video_entities_sign', 'video_entities_ball game', 'video_entities_house', 'video_entities_vehicle', 'video_entities_basketball', 'video_entities_clothing', 'video_entities_sneakers', 'video_entities_tights', 'video_entities_sunglasses', 'video_entities_spandex', 'video_entities_facial expression', 'video_entities_mouth', 'video_entities_leggings', 'video_entities_bird', 'video_entities_outerwear', 'video_entities_tree', 'video_entities_samsung', 'video_entities_ios', 'video_entities_android', 'video_entities_electronic device', 'video_entities_technology', 'video_entities_gadget', 'video_entities_muscle', 'video_entities_t-shirt', 'video_entities_standing', 'video_entities_head', 'video_entities_samsung galaxy', 'video_entities_service', 'video_entities_shoulder', 'video_entities_communication device', 'video_entities_eyebrow', 'video_entities_sitting', 'video_entities_weight training', 'video_entities_forehead', 'video_entities_iphone', 'video_entities_consumer electronics', 'video_entities_hair', 'video_entities_window blind', 'video_entities_training', 'video_entities_smile', 'video_entities_black hair', 'video_entities_necklace']

# %%
[ if]
